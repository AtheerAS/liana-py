# %% [markdown]
# # lrdata to MuData

# %%
import muon as mu
import anndata as ad
import os.path
from pathlib import Path
import scanpy as sc
import liana as li
from liana.method.sc import lrdata_to_mudata
import mudata as md

# %%
IN  = Path("/g/stegle/aalsayah/repos/data/merfish")
OUT = Path("/g/stegle/aalsayah/repos/data/merfish")

# %%
mdata =     lrdata_to_mudata(
        lrdata_path= (IN / "lrdata_animal2_C57BL6J-2.034.h5ad"),
        output_path=OUT,
        output_name="lrdata_animal2_C57BL6J-2.034.h5mu",
        filter_views=True, min_genes=10, min_cells=10, verbose=True,
    )
# Out:
# Loading lrdata from: /g/stegle/aalsayah/repos/data/merfish/lrdata_animal2_C57BL6J-2.034.h5ad
# Total variables: 1250
# Variables with a prefix pattern '<prefix>^': 1250
# Built view 'GABAergic_neuron' from raw prefix 'GABAergic neuron': 49115 cells × 96 features
# Built view 'glutamatergic_neuron' from raw prefix 'glutamatergic neuron': 49115 cells × 97 features
# Built view 'choroid_plexus_epithelial_cell' from raw prefix 'choroid plexus epithelial cell': 49115 cells × 59 features
# Built view 'neuroblast_sensu_Vertebrata' from raw prefix 'neuroblast (sensu Vertebrata)': 49115 cells × 54 features
# Built view 'lymphocyte' from raw prefix 'lymphocyte': 49115 cells × 32 features
# Built view 'astrocyte' from raw prefix 'astrocyte': 49115 cells × 93 features
# Built view 'glycinergic_neuron' from raw prefix 'glycinergic neuron': 49115 cells × 22 features
# Built view 'oligodendrocyte_precursor_cell' from raw prefix 'oligodendrocyte precursor cell': 49115 cells × 84 features
# Built view 'pericyte' from raw prefix 'pericyte': 49115 cells × 83 features
# Built view 'monocyte' from raw prefix 'monocyte': 49115 cells × 14 features
# Built view 'tanycyte' from raw prefix 'tanycyte': 49115 cells × 49 features
# Built view 'endothelial_cell' from raw prefix 'endothelial cell': 49115 cells × 90 features
# Built view 'microglial_cell' from raw prefix 'microglial cell': 49115 cells × 82 features
# Built view 'smooth_muscle_cell' from raw prefix 'smooth muscle cell': 49115 cells × 74 features
# Built view 'ependymal_cell' from raw prefix 'ependymal cell': 49115 cells × 74 features
# Built view 'vascular_leptomeningeal_cell' from raw prefix 'vascular leptomeningeal cell': 49115 cells × 65 features
# Built view 'dendritic_cell' from raw prefix 'dendritic cell': 49115 cells × 18 features
# Built view 'oligodendrocyte' from raw prefix 'oligodendrocyte': 49115 cells × 87 features
# Built view 'dopaminergic_neuron' from raw prefix 'dopaminergic neuron': 49115 cells × 20 features
# Built view 'macrophage' from raw prefix 'macrophage': 49115 cells × 57 features
# /g/stegle/aalsayah/Miniforge3/envs/liana_env/lib/python3.10/site-packages/mudata/_core/mudata.py:1598: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
# /g/stegle/aalsayah/Miniforge3/envs/liana_env/lib/python3.10/site-packages/mudata/_core/mudata.py:1461: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
# Processing modality: GABAergic_neuron
# Before filtering: 49115 cells × 96 genes
# After filtering:  4502 cells × 96 genes
# Removed cells:    44613
# Removed Interactions:    0
#
# Processing modality: glutamatergic_neuron
# Before filtering: 49115 cells × 97 genes
# After filtering:  7695 cells × 97 genes
# Removed cells:    41420
# Removed Interactions:    0
#
# Processing modality: choroid_plexus_epithelial_cell
# Before filtering: 49115 cells × 59 genes
# After filtering:  51 cells × 24 genes
# Removed cells:    49064
# Removed Interactions:    35
#
# Processing modality: neuroblast_sensu_Vertebrata
# Before filtering: 49115 cells × 54 genes
# After filtering:  20 cells × 11 genes
# Removed cells:    49095
# Removed Interactions:    43
#
# Processing modality: lymphocyte
# Before filtering: 49115 cells × 32 genes
# After filtering:  0 cells × 0 genes
# Removed cells:    49115
# Removed Interactions:    32
#
# Processing modality: astrocyte
# Before filtering: 49115 cells × 93 genes
# After filtering:  266 cells × 60 genes
# Removed cells:    48849
# Removed Interactions:    33
#
# Processing modality: glycinergic_neuron
# Before filtering: 49115 cells × 22 genes
# After filtering:  0 cells × 0 genes
# Removed cells:    49115
# Removed Interactions:    22
#
# Processing modality: oligodendrocyte_precursor_cell
# Before filtering: 49115 cells × 84 genes
# After filtering:  58 cells × 20 genes
# Removed cells:    49057
# Removed Interactions:    64
#
# Processing modality: pericyte
# Before filtering: 49115 cells × 83 genes
# After filtering:  14 cells × 0 genes
# Removed cells:    49101
# Removed Interactions:    83
#
# Processing modality: monocyte
# Before filtering: 49115 cells × 14 genes
# After filtering:  0 cells × 0 genes
# Removed cells:    49115
# Removed Interactions:    14
#
# Processing modality: tanycyte
# Before filtering: 49115 cells × 49 genes
# After filtering:  4 cells × 0 genes
# Removed cells:    49111
# Removed Interactions:    49
#
# Processing modality: endothelial_cell
# Before filtering: 49115 cells × 90 genes
# After filtering:  175 cells × 49 genes
# Removed cells:    48940
# Removed Interactions:    41
#
# Processing modality: microglial_cell
# Before filtering: 49115 cells × 82 genes
# After filtering:  22 cells × 7 genes
# Removed cells:    49093
# Removed Interactions:    75
#
# Processing modality: smooth_muscle_cell
# Before filtering: 49115 cells × 74 genes
# After filtering:  41 cells × 20 genes
# Removed cells:    49074
# Removed Interactions:    54
#
# Processing modality: ependymal_cell
# Before filtering: 49115 cells × 74 genes
# After filtering:  24 cells × 10 genes
# Removed cells:    49091
# Removed Interactions:    64
#
# Processing modality: vascular_leptomeningeal_cell
# Before filtering: 49115 cells × 65 genes
# After filtering:  54 cells × 24 genes
# Removed cells:    49061
# Removed Interactions:    41
#
# Processing modality: dendritic_cell
# Before filtering: 49115 cells × 18 genes
# After filtering:  0 cells × 0 genes
# Removed cells:    49115
# Removed Interactions:    18
#
# Processing modality: oligodendrocyte
# Before filtering: 49115 cells × 87 genes
# After filtering:  150 cells × 48 genes
# Removed cells:    48965
# Removed Interactions:    39
#
# Processing modality: dopaminergic_neuron
# Before filtering: 49115 cells × 20 genes
# After filtering:  0 cells × 0 genes
# Removed cells:    49115
# Removed Interactions:    20
#
# Processing modality: macrophage
# Before filtering: 49115 cells × 57 genes
# After filtering:  0 cells × 0 genes
# Removed cells:    49115
# Removed Interactions:    57
#
# Writing MuData to: /g/stegle/aalsayah/repos/data/merfish/lrdata_animal2_C57BL6J-2.034.h5mu
# /g/stegle/aalsayah/Miniforge3/envs/liana_env/lib/python3.10/site-packages/mudata/_core/mudata.py:1598: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
# /g/stegle/aalsayah/Miniforge3/envs/liana_env/lib/python3.10/site-packages/mudata/_core/mudata.py:1461: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.

# %%
data_path = Path("/g/stegle/aalsayah/repos/data/mudata_objects/")
model_path = Path("/g/stegle/aalsayah/repos/data/models_obj")
mdata = md.read(data_path/  "crc_222.mudata.h5mu")
# Out:
# /g/stegle/aalsayah/Miniforge3/envs/liana_env/lib/python3.10/site-packages/mudata/_core/mudata.py:1598: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
# /g/stegle/aalsayah/Miniforge3/envs/liana_env/lib/python3.10/site-packages/mudata/_core/mudata.py:1461: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.

# %%
mdata.mod["mye2"].var_names
# Out:
# Index(['mye2^COL6A1^CD44', 'mye2^COL6A2^CD44', 'mye2^COL1A1^CD44',
#        'mye2^LAMB1^CD44', 'mye2^COL4A1^CD44', 'mye2^COL4A2^CD44',
#        'mye2^LGALS9^CD44', 'mye2^COL1A2^CD44', 'mye2^COL1A1^SDC1',
#        'mye2^COL6A1^SDC1', 'mye2^COL4A1^SDC1', 'mye2^MIF^CD44_CD74'],
#       dtype='object')

# %%
mdata
# Out:
# MuData object with n_obs × n_vars = 19143 × 312
#   var:	'n_cells'
#   14 modalities
#     epi4:	4094 x 28
#       obs:	'fov', 'Area', 'AspectRatio', 'CenterX_local_px', 'CenterY_local_px', 'Width', 'Height', 'Mean.PanCK', 'Max.PanCK', 'Mean.CD68_CK8_18', 'Max.CD68_CK8_18', 'Mean.CD298_B2M', 'Max.CD298_B2M', 'Mean.CD45', 'Max.CD45', 'Mean.DAPI', 'Max.DAPI', 'cell_id', 'Dash', 'ISH.concentration', 'Panel', 'Run_Tissue_name', 'Run_name', 'assay_type', 'dualfiles', 'tissue', 'version', 'slide_ID', 'CenterX_global_px', 'CenterY_global_px', 'cell_ID', 'unassignedTranscripts', 'median_RNA', 'RNA_quantile_0.75', 'RNA_quantile_0.8', 'RNA_quantile_0.85', 'RNA_quantile_0.9', 'RNA_quantile_0.95', 'RNA_quantile_0.99', 'nCount_RNA', 'nFeature_RNA', 'median_negprobes', 'negprobes_quantile_0.75', 'negprobes_quantile_0.8', 'negprobes_quantile_0.85', 'negprobes_quantile_0.9', 'negprobes_quantile_0.95', 'negprobes_quantile_0.99', 'nCount_negprobes', 'nFeature_negprobes', 'median_falsecode', 'falsecode_quantile_0.75', 'falsecode_quantile_0.8', 'falsecode_quantile_0.85', 'falsecode_quantile_0.9', 'falsecode_quantile_0.95', 'falsecode_quantile_0.99', 'nCount_falsecode', 'nFeature_falsecode', 'Area.um2', 'cell', 'CenterX_local_mm', 'CenterY_local_mm', 'CenterX_global_mm', 'CenterY_global_mm', 'run', 'rep', 'sec', 'did', 'sid', 'pid', 'fil', 'typ', 'roi', 'ctx', 'trj', 'ist', 'lv1', 'jst', 'lv2', 'n_genes', 'CenterX_um', 'CenterY_um'
#       var:	'n_cells'
#       uns:	'X_name', 'global_score', 'log1p', 'moranI', 'th_d', 'th_fc', 'th_m', 'th_n', 'th_np'
#       obsm:	'PCA.epi', 'PCA.fil', 'spatial'
#       obsp:	'spatial_connectivities'
#     epi2:	15624 x 23
#       obs:	'fov', 'Area', 'AspectRatio', 'CenterX_local_px', 'CenterY_local_px', 'Width', 'Height', 'Mean.PanCK', 'Max.PanCK', 'Mean.CD68_CK8_18', 'Max.CD68_CK8_18', 'Mean.CD298_B2M', 'Max.CD298_B2M', 'Mean.CD45', 'Max.CD45', 'Mean.DAPI', 'Max.DAPI', 'cell_id', 'Dash', 'ISH.concentration', 'Panel', 'Run_Tissue_name', 'Run_name', 'assay_type', 'dualfiles', 'tissue', 'version', 'slide_ID', 'CenterX_global_px', 'CenterY_global_px', 'cell_ID', 'unassignedTranscripts', 'median_RNA', 'RNA_quantile_0.75', 'RNA_quantile_0.8', 'RNA_quantile_0.85', 'RNA_quantile_0.9', 'RNA_quantile_0.95', 'RNA_quantile_0.99', 'nCount_RNA', 'nFeature_RNA', 'median_negprobes', 'negprobes_quantile_0.75', 'negprobes_quantile_0.8', 'negprobes_quantile_0.85', 'negprobes_quantile_0.9', 'negprobes_quantile_0.95', 'negprobes_quantile_0.99', 'nCount_negprobes', 'nFeature_negprobes', 'median_falsecode', 'falsecode_quantile_0.75', 'falsecode_quantile_0.8', 'falsecode_quantile_0.85', 'falsecode_quantile_0.9', 'falsecode_quantile_0.95', 'falsecode_quantile_0.99', 'nCount_falsecode', 'nFeature_falsecode', 'Area.um2', 'cell', 'CenterX_local_mm', 'CenterY_local_mm', 'CenterX_global_mm', 'CenterY_global_mm', 'run', 'rep', 'sec', 'did', 'sid', 'pid', 'fil', 'typ', 'roi', 'ctx', 'trj', 'ist', 'lv1', 'jst', 'lv2', 'n_genes', 'CenterX_um', 'CenterY_um'
#       var:	'n_cells'
#       uns:	'X_name', 'global_score', 'log1p', 'moranI', 'th_d', 'th_fc', 'th_m', 'th_n', 'th_np'
#       obsm:	'PCA.epi', 'PCA.fil', 'spatial'
#       obsp:	'spatial_connectivities'
#     mye1:	5264 x 24
#       obs:	'fov', 'Area', 'AspectRatio', 'CenterX_local_px', 'CenterY_local_px', 'Width', 'Height', 'Mean.PanCK', 'Max.PanCK', 'Mean.CD68_CK8_18', 'Max.CD68_CK8_18', 'Mean.CD298_B2M', 'Max.CD298_B2M', 'Mean.CD45', 'Max.CD45', 'Mean.DAPI', 'Max.DAPI', 'cell_id', 'Dash', 'ISH.concentration', 'Panel', 'Run_Tissue_name', 'Run_name', 'assay_type', 'dualfiles', 'tissue', 'version', 'slide_ID', 'CenterX_global_px', 'CenterY_global_px', 'cell_ID', 'unassignedTranscripts', 'median_RNA', 'RNA_quantile_0.75', 'RNA_quantile_0.8', 'RNA_quantile_0.85', 'RNA_quantile_0.9', 'RNA_quantile_0.95', 'RNA_quantile_0.99', 'nCount_RNA', 'nFeature_RNA', 'median_negprobes', 'negprobes_quantile_0.75', 'negprobes_quantile_0.8', 'negprobes_quantile_0.85', 'negprobes_quantile_0.9', 'negprobes_quantile_0.95', 'negprobes_quantile_0.99', 'nCount_negprobes', 'nFeature_negprobes', 'median_falsecode', 'falsecode_quantile_0.75', 'falsecode_quantile_0.8', 'falsecode_quantile_0.85', 'falsecode_quantile_0.9', 'falsecode_quantile_0.95', 'falsecode_quantile_0.99', 'nCount_falsecode', 'nFeature_falsecode', 'Area.um2', 'cell', 'CenterX_local_mm', 'CenterY_local_mm', 'CenterX_global_mm', 'CenterY_global_mm', 'run', 'rep', 'sec', 'did', 'sid', 'pid', 'fil', 'typ', 'roi', 'ctx', 'trj', 'ist', 'lv1', 'jst', 'lv2', 'n_genes', 'CenterX_um', 'CenterY_um'
#       var:	'n_cells'
#       uns:	'X_name', 'global_score', 'log1p', 'moranI', 'th_d', 'th_fc', 'th_m', 'th_n', 'th_np'
#       obsm:	'PCA.epi', 'PCA.fil', 'spatial'
#       obsp:	'spatial_connectivities'
#     mye2:	27 x 12
#       obs:	'fov', 'Area', 'AspectRatio', 'CenterX_local_px', 'CenterY_local_px', 'Width', 'Height', 'Mean.PanCK', 'Max.PanCK', 'Mean.CD68_CK8_18', 'Max.CD68_CK8_18', 'Mean.CD298_B2M', 'Max.CD298_B2M', 'Mean.CD45', 'Max.CD45', 'Mean.DAPI', 'Max.DAPI', 'cell_id', 'Dash', 'ISH.concentration', 'Panel', 'Run_Tissue_name', 'Run_name', 'assay_type', 'dualfiles', 'tissue', 'version', 'slide_ID', 'CenterX_global_px', 'CenterY_global_px', 'cell_ID', 'unassignedTranscripts', 'median_RNA', 'RNA_quantile_0.75', 'RNA_quantile_0.8', 'RNA_quantile_0.85', 'RNA_quantile_0.9', 'RNA_quantile_0.95', 'RNA_quantile_0.99', 'nCount_RNA', 'nFeature_RNA', 'median_negprobes', 'negprobes_quantile_0.75', 'negprobes_quantile_0.8', 'negprobes_quantile_0.85', 'negprobes_quantile_0.9', 'negprobes_quantile_0.95', 'negprobes_quantile_0.99', 'nCount_negprobes', 'nFeature_negprobes', 'median_falsecode', 'falsecode_quantile_0.75', 'falsecode_quantile_0.8', 'falsecode_quantile_0.85', 'falsecode_quantile_0.9', 'falsecode_quantile_0.95', 'falsecode_quantile_0.99', 'nCount_falsecode', 'nFeature_falsecode', 'Area.um2', 'cell', 'CenterX_local_mm', 'CenterY_local_mm', 'CenterX_global_mm', 'CenterY_global_mm', 'run', 'rep', 'sec', 'did', 'sid', 'pid', 'fil', 'typ', 'roi', 'ctx', 'trj', 'ist', 'lv1', 'jst', 'lv2', 'n_genes', 'CenterX_um', 'CenterY_um'
#       var:	'n_cells'
#       uns:	'X_name', 'global_score', 'log1p', 'moranI', 'th_d', 'th_fc', 'th_m', 'th_n', 'th_np'
#       obsm:	'PCA.epi', 'PCA.fil', 'spatial'
#       obsp:	'spatial_connectivities'
#     fib2:	12079 x 26
#       obs:	'fov', 'Area', 'AspectRatio', 'CenterX_local_px', 'CenterY_local_px', 'Width', 'Height', 'Mean.PanCK', 'Max.PanCK', 'Mean.CD68_CK8_18', 'Max.CD68_CK8_18', 'Mean.CD298_B2M', 'Max.CD298_B2M', 'Mean.CD45', 'Max.CD45', 'Mean.DAPI', 'Max.DAPI', 'cell_id', 'Dash', 'ISH.concentration', 'Panel', 'Run_Tissue_name', 'Run_name', 'assay_type', 'dualfiles', 'tissue', 'version', 'slide_ID', 'CenterX_global_px', 'CenterY_global_px', 'cell_ID', 'unassignedTranscripts', 'median_RNA', 'RNA_quantile_0.75', 'RNA_quantile_0.8', 'RNA_quantile_0.85', 'RNA_quantile_0.9', 'RNA_quantile_0.95', 'RNA_quantile_0.99', 'nCount_RNA', 'nFeature_RNA', 'median_negprobes', 'negprobes_quantile_0.75', 'negprobes_quantile_0.8', 'negprobes_quantile_0.85', 'negprobes_quantile_0.9', 'negprobes_quantile_0.95', 'negprobes_quantile_0.99', 'nCount_negprobes', 'nFeature_negprobes', 'median_falsecode', 'falsecode_quantile_0.75', 'falsecode_quantile_0.8', 'falsecode_quantile_0.85', 'falsecode_quantile_0.9', 'falsecode_quantile_0.95', 'falsecode_quantile_0.99', 'nCount_falsecode', 'nFeature_falsecode', 'Area.um2', 'cell', 'CenterX_local_mm', 'CenterY_local_mm', 'CenterX_global_mm', 'CenterY_global_mm', 'run', 'rep', 'sec', 'did', 'sid', 'pid', 'fil', 'typ', 'roi', 'ctx', 'trj', 'ist', 'lv1', 'jst', 'lv2', 'n_genes', 'CenterX_um', 'CenterY_um'
#       var:	'n_cells'
#       uns:	'X_name', 'global_score', 'log1p', 'moranI', 'th_d', 'th_fc', 'th_m', 'th_n', 'th_np'
#       obsm:	'PCA.epi', 'PCA.fil', 'spatial'
#       obsp:	'spatial_connectivities'
#     EC:	1413 x 25
#       obs:	'fov', 'Area', 'AspectRatio', 'CenterX_local_px', 'CenterY_local_px', 'Width', 'Height', 'Mean.PanCK', 'Max.PanCK', 'Mean.CD68_CK8_18', 'Max.CD68_CK8_18', 'Mean.CD298_B2M', 'Max.CD298_B2M', 'Mean.CD45', 'Max.CD45', 'Mean.DAPI', 'Max.DAPI', 'cell_id', 'Dash', 'ISH.concentration', 'Panel', 'Run_Tissue_name', 'Run_name', 'assay_type', 'dualfiles', 'tissue', 'version', 'slide_ID', 'CenterX_global_px', 'CenterY_global_px', 'cell_ID', 'unassignedTranscripts', 'median_RNA', 'RNA_quantile_0.75', 'RNA_quantile_0.8', 'RNA_quantile_0.85', 'RNA_quantile_0.9', 'RNA_quantile_0.95', 'RNA_quantile_0.99', 'nCount_RNA', 'nFeature_RNA', 'median_negprobes', 'negprobes_quantile_0.75', 'negprobes_quantile_0.8', 'negprobes_quantile_0.85', 'negprobes_quantile_0.9', 'negprobes_quantile_0.95', 'negprobes_quantile_0.99', 'nCount_negprobes', 'nFeature_negprobes', 'median_falsecode', 'falsecode_quantile_0.75', 'falsecode_quantile_0.8', 'falsecode_quantile_0.85', 'falsecode_quantile_0.9', 'falsecode_quantile_0.95', 'falsecode_quantile_0.99', 'nCount_falsecode', 'nFeature_falsecode', 'Area.um2', 'cell', 'CenterX_local_mm', 'CenterY_local_mm', 'CenterX_global_mm', 'CenterY_global_mm', 'run', 'rep', 'sec', 'did', 'sid', 'pid', 'fil', 'typ', 'roi', 'ctx', 'trj', 'ist', 'lv1', 'jst', 'lv2', 'n_genes', 'CenterX_um', 'CenterY_um'
#       var:	'n_cells'
#       uns:	'X_name', 'global_score', 'log1p', 'moranI', 'th_d', 'th_fc', 'th_m', 'th_n', 'th_np'
#       obsm:	'PCA.epi', 'PCA.fil', 'spatial'
#       obsp:	'spatial_connectivities'
#     PC_IgA:	2845 x 25
#       obs:	'fov', 'Area', 'AspectRatio', 'CenterX_local_px', 'CenterY_local_px', 'Width', 'Height', 'Mean.PanCK', 'Max.PanCK', 'Mean.CD68_CK8_18', 'Max.CD68_CK8_18', 'Mean.CD298_B2M', 'Max.CD298_B2M', 'Mean.CD45', 'Max.CD45', 'Mean.DAPI', 'Max.DAPI', 'cell_id', 'Dash', 'ISH.concentration', 'Panel', 'Run_Tissue_name', 'Run_name', 'assay_type', 'dualfiles', 'tissue', 'version', 'slide_ID', 'CenterX_global_px', 'CenterY_global_px', 'cell_ID', 'unassignedTranscripts', 'median_RNA', 'RNA_quantile_0.75', 'RNA_quantile_0.8', 'RNA_quantile_0.85', 'RNA_quantile_0.9', 'RNA_quantile_0.95', 'RNA_quantile_0.99', 'nCount_RNA', 'nFeature_RNA', 'median_negprobes', 'negprobes_quantile_0.75', 'negprobes_quantile_0.8', 'negprobes_quantile_0.85', 'negprobes_quantile_0.9', 'negprobes_quantile_0.95', 'negprobes_quantile_0.99', 'nCount_negprobes', 'nFeature_negprobes', 'median_falsecode', 'falsecode_quantile_0.75', 'falsecode_quantile_0.8', 'falsecode_quantile_0.85', 'falsecode_quantile_0.9', 'falsecode_quantile_0.95', 'falsecode_quantile_0.99', 'nCount_falsecode', 'nFeature_falsecode', 'Area.um2', 'cell', 'CenterX_local_mm', 'CenterY_local_mm', 'CenterX_global_mm', 'CenterY_global_mm', 'run', 'rep', 'sec', 'did', 'sid', 'pid', 'fil', 'typ', 'roi', 'ctx', 'trj', 'ist', 'lv1', 'jst', 'lv2', 'n_genes', 'CenterX_um', 'CenterY_um'
#       var:	'n_cells'
#       uns:	'X_name', 'global_score', 'log1p', 'moranI', 'th_d', 'th_fc', 'th_m', 'th_n', 'th_np'
#       obsm:	'PCA.epi', 'PCA.fil', 'spatial'
#       obsp:	'spatial_connectivities'
#     PC_IgG:	2414 x 25
#       obs:	'fov', 'Area', 'AspectRatio', 'CenterX_local_px', 'CenterY_local_px', 'Width', 'Height', 'Mean.PanCK', 'Max.PanCK', 'Mean.CD68_CK8_18', 'Max.CD68_CK8_18', 'Mean.CD298_B2M', 'Max.CD298_B2M', 'Mean.CD45', 'Max.CD45', 'Mean.DAPI', 'Max.DAPI', 'cell_id', 'Dash', 'ISH.concentration', 'Panel', 'Run_Tissue_name', 'Run_name', 'assay_type', 'dualfiles', 'tissue', 'version', 'slide_ID', 'CenterX_global_px', 'CenterY_global_px', 'cell_ID', 'unassignedTranscripts', 'median_RNA', 'RNA_quantile_0.75', 'RNA_quantile_0.8', 'RNA_quantile_0.85', 'RNA_quantile_0.9', 'RNA_quantile_0.95', 'RNA_quantile_0.99', 'nCount_RNA', 'nFeature_RNA', 'median_negprobes', 'negprobes_quantile_0.75', 'negprobes_quantile_0.8', 'negprobes_quantile_0.85', 'negprobes_quantile_0.9', 'negprobes_quantile_0.95', 'negprobes_quantile_0.99', 'nCount_negprobes', 'nFeature_negprobes', 'median_falsecode', 'falsecode_quantile_0.75', 'falsecode_quantile_0.8', 'falsecode_quantile_0.85', 'falsecode_quantile_0.9', 'falsecode_quantile_0.95', 'falsecode_quantile_0.99', 'nCount_falsecode', 'nFeature_falsecode', 'Area.um2', 'cell', 'CenterX_local_mm', 'CenterY_local_mm', 'CenterX_global_mm', 'CenterY_global_mm', 'run', 'rep', 'sec', 'did', 'sid', 'pid', 'fil', 'typ', 'roi', 'ctx', 'trj', 'ist', 'lv1', 'jst', 'lv2', 'n_genes', 'CenterX_um', 'CenterY_um'
#       var:	'n_cells'
#       uns:	'X_name', 'global_score', 'log1p', 'moranI', 'th_d', 'th_fc', 'th_m', 'th_n', 'th_np'
#       obsm:	'PCA.epi', 'PCA.fil', 'spatial'
#       obsp:	'spatial_connectivities'
#     epi1:	4769 x 21
#       obs:	'fov', 'Area', 'AspectRatio', 'CenterX_local_px', 'CenterY_local_px', 'Width', 'Height', 'Mean.PanCK', 'Max.PanCK', 'Mean.CD68_CK8_18', 'Max.CD68_CK8_18', 'Mean.CD298_B2M', 'Max.CD298_B2M', 'Mean.CD45', 'Max.CD45', 'Mean.DAPI', 'Max.DAPI', 'cell_id', 'Dash', 'ISH.concentration', 'Panel', 'Run_Tissue_name', 'Run_name', 'assay_type', 'dualfiles', 'tissue', 'version', 'slide_ID', 'CenterX_global_px', 'CenterY_global_px', 'cell_ID', 'unassignedTranscripts', 'median_RNA', 'RNA_quantile_0.75', 'RNA_quantile_0.8', 'RNA_quantile_0.85', 'RNA_quantile_0.9', 'RNA_quantile_0.95', 'RNA_quantile_0.99', 'nCount_RNA', 'nFeature_RNA', 'median_negprobes', 'negprobes_quantile_0.75', 'negprobes_quantile_0.8', 'negprobes_quantile_0.85', 'negprobes_quantile_0.9', 'negprobes_quantile_0.95', 'negprobes_quantile_0.99', 'nCount_negprobes', 'nFeature_negprobes', 'median_falsecode', 'falsecode_quantile_0.75', 'falsecode_quantile_0.8', 'falsecode_quantile_0.85', 'falsecode_quantile_0.9', 'falsecode_quantile_0.95', 'falsecode_quantile_0.99', 'nCount_falsecode', 'nFeature_falsecode', 'Area.um2', 'cell', 'CenterX_local_mm', 'CenterY_local_mm', 'CenterX_global_mm', 'CenterY_global_mm', 'run', 'rep', 'sec', 'did', 'sid', 'pid', 'fil', 'typ', 'roi', 'ctx', 'trj', 'ist', 'lv1', 'jst', 'lv2', 'n_genes', 'CenterX_um', 'CenterY_um'
#       var:	'n_cells'
#       uns:	'X_name', 'global_score', 'log1p', 'moranI', 'th_d', 'th_fc', 'th_m', 'th_n', 'th_np'
#       obsm:	'PCA.epi', 'PCA.fil', 'spatial'
#       obsp:	'spatial_connectivities'
#     TC:	54 x 15
#       obs:	'fov', 'Area', 'AspectRatio', 'CenterX_local_px', 'CenterY_local_px', 'Width', 'Height', 'Mean.PanCK', 'Max.PanCK', 'Mean.CD68_CK8_18', 'Max.CD68_CK8_18', 'Mean.CD298_B2M', 'Max.CD298_B2M', 'Mean.CD45', 'Max.CD45', 'Mean.DAPI', 'Max.DAPI', 'cell_id', 'Dash', 'ISH.concentration', 'Panel', 'Run_Tissue_name', 'Run_name', 'assay_type', 'dualfiles', 'tissue', 'version', 'slide_ID', 'CenterX_global_px', 'CenterY_global_px', 'cell_ID', 'unassignedTranscripts', 'median_RNA', 'RNA_quantile_0.75', 'RNA_quantile_0.8', 'RNA_quantile_0.85', 'RNA_quantile_0.9', 'RNA_quantile_0.95', 'RNA_quantile_0.99', 'nCount_RNA', 'nFeature_RNA', 'median_negprobes', 'negprobes_quantile_0.75', 'negprobes_quantile_0.8', 'negprobes_quantile_0.85', 'negprobes_quantile_0.9', 'negprobes_quantile_0.95', 'negprobes_quantile_0.99', 'nCount_negprobes', 'nFeature_negprobes', 'median_falsecode', 'falsecode_quantile_0.75', 'falsecode_quantile_0.8', 'falsecode_quantile_0.85', 'falsecode_quantile_0.9', 'falsecode_quantile_0.95', 'falsecode_quantile_0.99', 'nCount_falsecode', 'nFeature_falsecode', 'Area.um2', 'cell', 'CenterX_local_mm', 'CenterY_local_mm', 'CenterX_global_mm', 'CenterY_global_mm', 'run', 'rep', 'sec', 'did', 'sid', 'pid', 'fil', 'typ', 'roi', 'ctx', 'trj', 'ist', 'lv1', 'jst', 'lv2', 'n_genes', 'CenterX_um', 'CenterY_um'
#       var:	'n_cells'
#       uns:	'X_name', 'global_score', 'log1p', 'moranI', 'th_d', 'th_fc', 'th_m', 'th_n', 'th_np'
#       obsm:	'PCA.epi', 'PCA.fil', 'spatial'
#       obsp:	'spatial_connectivities'
#     SMC:	284 x 19
#       obs:	'fov', 'Area', 'AspectRatio', 'CenterX_local_px', 'CenterY_local_px', 'Width', 'Height', 'Mean.PanCK', 'Max.PanCK', 'Mean.CD68_CK8_18', 'Max.CD68_CK8_18', 'Mean.CD298_B2M', 'Max.CD298_B2M', 'Mean.CD45', 'Max.CD45', 'Mean.DAPI', 'Max.DAPI', 'cell_id', 'Dash', 'ISH.concentration', 'Panel', 'Run_Tissue_name', 'Run_name', 'assay_type', 'dualfiles', 'tissue', 'version', 'slide_ID', 'CenterX_global_px', 'CenterY_global_px', 'cell_ID', 'unassignedTranscripts', 'median_RNA', 'RNA_quantile_0.75', 'RNA_quantile_0.8', 'RNA_quantile_0.85', 'RNA_quantile_0.9', 'RNA_quantile_0.95', 'RNA_quantile_0.99', 'nCount_RNA', 'nFeature_RNA', 'median_negprobes', 'negprobes_quantile_0.75', 'negprobes_quantile_0.8', 'negprobes_quantile_0.85', 'negprobes_quantile_0.9', 'negprobes_quantile_0.95', 'negprobes_quantile_0.99', 'nCount_negprobes', 'nFeature_negprobes', 'median_falsecode', 'falsecode_quantile_0.75', 'falsecode_quantile_0.8', 'falsecode_quantile_0.85', 'falsecode_quantile_0.9', 'falsecode_quantile_0.95', 'falsecode_quantile_0.99', 'nCount_falsecode', 'nFeature_falsecode', 'Area.um2', 'cell', 'CenterX_local_mm', 'CenterY_local_mm', 'CenterX_global_mm', 'CenterY_global_mm', 'run', 'rep', 'sec', 'did', 'sid', 'pid', 'fil', 'typ', 'roi', 'ctx', 'trj', 'ist', 'lv1', 'jst', 'lv2', 'n_genes', 'CenterX_um', 'CenterY_um'
#       var:	'n_cells'
#       uns:	'X_name', 'global_score', 'log1p', 'moranI', 'th_d', 'th_fc', 'th_m', 'th_n', 'th_np'
#       obsm:	'PCA.epi', 'PCA.fil', 'spatial'
#       obsp:	'spatial_connectivities'
#     fib1:	268 x 23
#       obs:	'fov', 'Area', 'AspectRatio', 'CenterX_local_px', 'CenterY_local_px', 'Width', 'Height', 'Mean.PanCK', 'Max.PanCK', 'Mean.CD68_CK8_18', 'Max.CD68_CK8_18', 'Mean.CD298_B2M', 'Max.CD298_B2M', 'Mean.CD45', 'Max.CD45', 'Mean.DAPI', 'Max.DAPI', 'cell_id', 'Dash', 'ISH.concentration', 'Panel', 'Run_Tissue_name', 'Run_name', 'assay_type', 'dualfiles', 'tissue', 'version', 'slide_ID', 'CenterX_global_px', 'CenterY_global_px', 'cell_ID', 'unassignedTranscripts', 'median_RNA', 'RNA_quantile_0.75', 'RNA_quantile_0.8', 'RNA_quantile_0.85', 'RNA_quantile_0.9', 'RNA_quantile_0.95', 'RNA_quantile_0.99', 'nCount_RNA', 'nFeature_RNA', 'median_negprobes', 'negprobes_quantile_0.75', 'negprobes_quantile_0.8', 'negprobes_quantile_0.85', 'negprobes_quantile_0.9', 'negprobes_quantile_0.95', 'negprobes_quantile_0.99', 'nCount_negprobes', 'nFeature_negprobes', 'median_falsecode', 'falsecode_quantile_0.75', 'falsecode_quantile_0.8', 'falsecode_quantile_0.85', 'falsecode_quantile_0.9', 'falsecode_quantile_0.95', 'falsecode_quantile_0.99', 'nCount_falsecode', 'nFeature_falsecode', 'Area.um2', 'cell', 'CenterX_local_mm', 'CenterY_local_mm', 'CenterX_global_mm', 'CenterY_global_mm', 'run', 'rep', 'sec', 'did', 'sid', 'pid', 'fil', 'typ', 'roi', 'ctx', 'trj', 'ist', 'lv1', 'jst', 'lv2', 'n_genes', 'CenterX_um', 'CenterY_um'
#       var:	'n_cells'
#       uns:	'X_name', 'global_score', 'log1p', 'moranI', 'th_d', 'th_fc', 'th_m', 'th_n', 'th_np'
#       obsm:	'PCA.epi', 'PCA.fil', 'spatial'
#       obsp:	'spatial_connectivities'
#     PC_IgM:	2410 x 24
#       obs:	'fov', 'Area', 'AspectRatio', 'CenterX_local_px', 'CenterY_local_px', 'Width', 'Height', 'Mean.PanCK', 'Max.PanCK', 'Mean.CD68_CK8_18', 'Max.CD68_CK8_18', 'Mean.CD298_B2M', 'Max.CD298_B2M', 'Mean.CD45', 'Max.CD45', 'Mean.DAPI', 'Max.DAPI', 'cell_id', 'Dash', 'ISH.concentration', 'Panel', 'Run_Tissue_name', 'Run_name', 'assay_type', 'dualfiles', 'tissue', 'version', 'slide_ID', 'CenterX_global_px', 'CenterY_global_px', 'cell_ID', 'unassignedTranscripts', 'median_RNA', 'RNA_quantile_0.75', 'RNA_quantile_0.8', 'RNA_quantile_0.85', 'RNA_quantile_0.9', 'RNA_quantile_0.95', 'RNA_quantile_0.99', 'nCount_RNA', 'nFeature_RNA', 'median_negprobes', 'negprobes_quantile_0.75', 'negprobes_quantile_0.8', 'negprobes_quantile_0.85', 'negprobes_quantile_0.9', 'negprobes_quantile_0.95', 'negprobes_quantile_0.99', 'nCount_negprobes', 'nFeature_negprobes', 'median_falsecode', 'falsecode_quantile_0.75', 'falsecode_quantile_0.8', 'falsecode_quantile_0.85', 'falsecode_quantile_0.9', 'falsecode_quantile_0.95', 'falsecode_quantile_0.99', 'nCount_falsecode', 'nFeature_falsecode', 'Area.um2', 'cell', 'CenterX_local_mm', 'CenterY_local_mm', 'CenterX_global_mm', 'CenterY_global_mm', 'run', 'rep', 'sec', 'did', 'sid', 'pid', 'fil', 'typ', 'roi', 'ctx', 'trj', 'ist', 'lv1', 'jst', 'lv2', 'n_genes', 'CenterX_um', 'CenterY_um'
#       var:	'n_cells'
#       uns:	'X_name', 'global_score', 'log1p', 'moranI', 'th_d', 'th_fc', 'th_m', 'th_n', 'th_np'
#       obsm:	'PCA.epi', 'PCA.fil', 'spatial'
#       obsp:	'spatial_connectivities'
#     epi3:	177 x 22
#       obs:	'fov', 'Area', 'AspectRatio', 'CenterX_local_px', 'CenterY_local_px', 'Width', 'Height', 'Mean.PanCK', 'Max.PanCK', 'Mean.CD68_CK8_18', 'Max.CD68_CK8_18', 'Mean.CD298_B2M', 'Max.CD298_B2M', 'Mean.CD45', 'Max.CD45', 'Mean.DAPI', 'Max.DAPI', 'cell_id', 'Dash', 'ISH.concentration', 'Panel', 'Run_Tissue_name', 'Run_name', 'assay_type', 'dualfiles', 'tissue', 'version', 'slide_ID', 'CenterX_global_px', 'CenterY_global_px', 'cell_ID', 'unassignedTranscripts', 'median_RNA', 'RNA_quantile_0.75', 'RNA_quantile_0.8', 'RNA_quantile_0.85', 'RNA_quantile_0.9', 'RNA_quantile_0.95', 'RNA_quantile_0.99', 'nCount_RNA', 'nFeature_RNA', 'median_negprobes', 'negprobes_quantile_0.75', 'negprobes_quantile_0.8', 'negprobes_quantile_0.85', 'negprobes_quantile_0.9', 'negprobes_quantile_0.95', 'negprobes_quantile_0.99', 'nCount_negprobes', 'nFeature_negprobes', 'median_falsecode', 'falsecode_quantile_0.75', 'falsecode_quantile_0.8', 'falsecode_quantile_0.85', 'falsecode_quantile_0.9', 'falsecode_quantile_0.95', 'falsecode_quantile_0.99', 'nCount_falsecode', 'nFeature_falsecode', 'Area.um2', 'cell', 'CenterX_local_mm', 'CenterY_local_mm', 'CenterX_global_mm', 'CenterY_global_mm', 'run', 'rep', 'sec', 'did', 'sid', 'pid', 'fil', 'typ', 'roi', 'ctx', 'trj', 'ist', 'lv1', 'jst', 'lv2', 'n_genes', 'CenterX_um', 'CenterY_um'
#       var:	'n_cells'
#       uns:	'X_name', 'global_score', 'log1p', 'moranI', 'th_d', 'th_fc', 'th_m', 'th_n', 'th_np'
#       obsm:	'PCA.epi', 'PCA.fil', 'spatial'
#       obsp:	'spatial_connectivities'
