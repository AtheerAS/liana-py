# %% [markdown]
# # lrdata to MuData

# %%
import muon as mu
import anndata as ad
import os.path
from pathlib import Path
import scanpy as sc
import liana as li
from liana.method.sc import lrdata_to_mudata
import mudata as md

# %%
IN  = Path("/g/stegle/aalsayah/repos/data/lrdata_processed")
OUT = Path("/g/stegle/aalsayah/repos/data/")

# %%
adata = sc.read(slide_tag / "slidetags/lrdata/SCP2170.h5ad")

# %%
IN  = Path("/g/stegle/aalsayah/repos/data/slidatag/slidetags/lrdata")
OUT = Path("/g/stegle/aalsayah/repos/data/slidatag/slidetags/mudata")

# %%
mdata =     lrdata_to_mudata(
        lrdata_path= (IN / "SCP2170.h5ad"),
        output_path=OUT,
        output_name="SCP2170.h5mu",
        filter_views=True, min_genes=5, min_cells=5, verbose=True,
    )
# Out:
# Loading lrdata from: /g/stegle/aalsayah/repos/data/slidatag/slidetags/lrdata/SCP2170.h5ad
# Total variables: 10608
# Variables with a prefix pattern '<prefix>^': 10608
# Built view 'Neuron_3' from raw prefix 'Neuron-3': 4623 cells × 497 features
# Built view 'Neuron_8' from raw prefix 'Neuron-8': 4623 cells × 412 features
# Built view 'Neuron_4' from raw prefix 'Neuron-4': 4623 cells × 481 features
# Built view 'Neuron_12' from raw prefix 'Neuron-12': 4623 cells × 449 features
# Built view 'Neuron_9' from raw prefix 'Neuron-9': 4623 cells × 486 features
# Built view 'Neuron_14' from raw prefix 'Neuron-14': 4623 cells × 399 features
# Built view 'Neuron_6' from raw prefix 'Neuron-6': 4623 cells × 565 features
# Built view 'Neuron_10' from raw prefix 'Neuron-10': 4623 cells × 430 features
# Built view 'Neuron_11' from raw prefix 'Neuron-11': 4623 cells × 497 features
# Built view 'Neuron_5' from raw prefix 'Neuron-5': 4623 cells × 602 features
# ...

# %%
IN  = Path("/g/stegle/aalsayah/repos/data/lrdata_processed")
OUT = Path("/g/stegle/aalsayah/repos/data/")

for f in IN.glob("*_lrdata.h5ad"):
    lrdata_to_mudata(
        lrdata_path=f,
        output_path=OUT,
        output_name=f.name.replace("_lrdata.h5ad", ".mudata.h5mu"),
        filter_views=True, min_genes=5, min_cells=5, verbose=True,
    )
# Out:
# Loading lrdata from: /g/stegle/aalsayah/repos/data/lrdata_processed/crc_110_lrdata.h5ad
# Total variables: 1509
# Variables with a prefix pattern '<prefix>^': 1509
# Built view 'epi4' from raw prefix 'epi4': 693377 cells × 122 features
# Built view 'epi1' from raw prefix 'epi1': 693377 cells × 80 features
# Built view 'epi3' from raw prefix 'epi3': 693377 cells × 111 features
# Built view 'epi2' from raw prefix 'epi2': 693377 cells × 118 features
# Built view 'fib2' from raw prefix 'fib2': 693377 cells × 114 features
# Built view 'mye1' from raw prefix 'mye1': 693377 cells × 113 features
# Built view 'mye2' from raw prefix 'mye2': 693377 cells × 106 features
# Built view 'BC' from raw prefix 'BC': 693377 cells × 85 features
# Built view 'EC' from raw prefix 'EC': 693377 cells × 113 features
# Built view 'TC' from raw prefix 'TC': 693377 cells × 105 features
# Built view 'PC_IgG' from raw prefix 'PC_IgG': 693377 cells × 107 features
# ...

# %%
data_path = Path("/g/stegle/aalsayah/repos/data/mudata_objects/")
model_path = Path("/g/stegle/aalsayah/repos/data/models_obj")
mdata = md.read(data_path/  "crc_222.mudata.h5mu")
# Out:
# /g/stegle/aalsayah/Miniforge3/envs/liana_env/lib/python3.10/site-packages/mudata/_core/mudata.py:1598: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
# /g/stegle/aalsayah/Miniforge3/envs/liana_env/lib/python3.10/site-packages/mudata/_core/mudata.py:1461: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.

# %%
mdata.mod["mye2"].var_names
# Out:
# Index(['mye2^COL6A1^CD44', 'mye2^COL6A2^CD44', 'mye2^COL1A1^CD44',
#        'mye2^LAMB1^CD44', 'mye2^COL4A1^CD44', 'mye2^COL4A2^CD44',
#        'mye2^LGALS9^CD44', 'mye2^COL1A2^CD44', 'mye2^COL1A1^SDC1',
#        'mye2^COL6A1^SDC1', 'mye2^COL4A1^SDC1', 'mye2^MIF^CD44_CD74'],
#       dtype='object')

# %%
mdata
# Out:
# MuData object with n_obs × n_vars = 19143 × 312
#   var:	'n_cells'
#   14 modalities
#     epi4:	4094 x 28
# ...
