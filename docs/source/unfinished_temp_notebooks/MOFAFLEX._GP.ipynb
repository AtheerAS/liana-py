# %% [markdown]
# # MOFA-Flex NORMAL

# %%
import os.path
from tempfile import TemporaryDirectory
from urllib.request import urlretrieve
import anndata as ad
import mudata as md
import numpy as np
import pandas as pd
import mofaflex as mfl
from plotnine import *
import os
from pathlib import Path
from anndata.compat import DaskArray
import dask.array as da


data_path = Path("/g/stegle/aalsayah/repos/data/mudata_objects/")
mdata = md.read(data_path/  "crc_231.mudata.h5mu")
md.set_options(pull_on_update=False) 


model = mfl.MOFAFLEX(
    mdata,
    mfl.ModelOptions(n_factors=15, factor_prior="Normal", likelihoods="Normal"),
    mfl.TrainingOptions(batch_size=2000, 
                        n_particles=10,
                        seed=1, 
                        lr=0.005,
                        max_epochs=500,
                        save_path= ('/g/stegle/aalsayah/repos/data/models_obj/crc_231.hdf5'),
                        early_stopper_patience=50)
                        )
# Out:
# INFO	Initializing factors using `random` method...
#   0%|                                                                                                  | 0/500…
# /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/util.py:288: UserWarning: Found non-auxiliary vars in guide but not model, consider marking these infer={'is_auxiliary': True}:
# {'_likelihoods.mye2._dispersion'}
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[5], line 21
#      17 mdata = md.read(data_path/  "crc_231.mudata.h5mu")
#      18 md.set_options(pull_on_update=False)
# ---> 21 model = mfl.MOFAFLEX(
#      22     mdata,
#      23     mfl.ModelOptions(n_factors=15, factor_prior="Normal", likelihoods="Normal"),
#      24     mfl.TrainingOptions(batch_size=2000,
#      25                         n_particles=10,
#      26                         seed=1,
#      27                         lr=0.005,
#      28                         max_epochs=500,
#      29                         save_path= ('/g/stegle/aalsayah/repos/data/models_obj/crc_231.hdf5'),
#      30                         early_stopper_patience=50)
#      31                         )
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/mofaflex/_core/mofaflex.py:280, in MOFAFLEX.__init__(self, data, *args)
#     277 self._sample_names = data.sample_names
#     278 self._feature_names = data.feature_names
# --> 280 self._fit(data, preprocessor)
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/mofaflex/_core/mofaflex.py:933, in MOFAFLEX._fit(self, data, preprocessor)
#     931         batch = collate((batch,), collate_fn_map=collate_fn_map)
#     932         with self._train_opts.device:
# --> 933             epoch_loss += svi.step(
#     934                 **batch["data"], covariates=batch["covariates"], guiding_vars=batch["guiding_vars"]
#     935             )
#     936 train_loss_elbo.append(epoch_loss)
#     937 if (
#     938     self._gp is not None
#     939     and len(self._gp_opts.warp_groups)
#     940     and i > 0
#     941     and not i % self._gp_opts.warp_interval
#     942 ):
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/infer/svi.py:145, in SVI.step(self, *args, **kwargs)
#     143 # get loss and compute gradients
#     144 with poutine.trace(param_only=True) as param_capture:
# --> 145     loss = self.loss_and_grads(self.model, self.guide, *args, **kwargs)
#     147 params = set(
#     148     site["value"].unconstrained() for site in param_capture.trace.nodes.values()
#     149 )
#     151 # actually perform gradient steps
#     152 # torch.optim objects gets instantiated for any params that haven't been seen yet
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/infer/trace_elbo.py:141, in Trace_ELBO.loss_and_grads(self, model, guide, *args, **kwargs)
#     139 # grab a trace from the generator
#     140 for model_trace, guide_trace in self._get_traces(model, guide, args, kwargs):
# --> 141     loss_particle, surrogate_loss_particle = self._differentiable_loss_particle(
#     142         model_trace, guide_trace
#     143     )
#     144     loss += loss_particle / self.num_particles
#     146     # collect parameters to train from model and guide
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/infer/trace_mean_field_elbo.py:144, in TraceMeanField_ELBO._differentiable_loss_particle(self, model_trace, guide_trace)
#     142 for name, guide_site in guide_trace.nodes.items():
#     143     if guide_site["type"] == "sample" and name not in model_trace.nodes:
# --> 144         assert guide_site["infer"].get("is_auxiliary")
#     145         if is_validation_enabled():
#     146             check_fully_reparametrized(guide_site)
#
# AssertionError:

# %%
del mdata.mod['mye2']
from mudata import MuData
mdata_new = MuData({mod: ad for mod, ad in mdata.mod.items()})

# %%
model = mfl.MOFAFLEX(
    mdata_new,
    mfl.ModelOptions(n_factors=15, factor_prior="Normal", likelihoods="Normal"),
    mfl.TrainingOptions(batch_size=2000, 
                        n_particles=10,
                        seed=1, 
                        lr=0.005,
                        max_epochs=500,
                        save_path= ('/g/stegle/aalsayah/repos/data/models_obj/crc_231.hdf5'),
                        early_stopper_patience=50)
                        )
# Out:
# INFO	Initializing factors using `random` method...
#   0%|                                                                                                  | 0/500…
# INFO	Saving results to /g/stegle/aalsayah/repos/data/models_obj/crc_231.hdf5...

# %% [markdown]
# ----

# %% [markdown]
# # Load Model

# %%
model = mfl.MOFAFLEX.load('/g/stegle/aalsayah/repos/data/models_obj/crc_210.hdf5')

# %%
# in the SAME Python/mofapy2 env you trained in
mfl.pl.variance_explained(model)

# %%
import os.path
from tempfile import TemporaryDirectory
from urllib.request import urlretrieve
import anndata as ad
import mudata as md
import numpy as np
import pandas as pd
import mofaflex as mfl
from plotnine import *
import os
from pathlib import Path
from anndata.compat import DaskArray
import dask.array as da
# Out:
# Importing the dtw module. When using in academic works please cite:
#   T. Giorgino. Computing and Visualizing Dynamic Time Warping Alignments in R: The dtw Package.
#   J. Stat. Soft., doi:10.18637/jss.v031.i07.

# %%
from mudata import MuData

# %%
data_path = Path("/g/stegle/aalsayah/repos/data/mudata_objects/")
mdata = md.read(data_path/  "crc_232.mudata.h5mu")
# Out:
# /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/mudata/_core/mudata.py:1598: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
# /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/mudata/_core/mudata.py:1461: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.

# %%
del mdata.mod['mye2']
del mdata.mod['PC_IgM']

mdata_new = MuData({mod: ad for mod, ad in mdata.mod.items()})
# Out:
# /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/mudata/_core/mudata.py:1598: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
# /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/mudata/_core/mudata.py:1461: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.

# %%
mdata_new.write_h5mu("/g/stegle/aalsayah/repos/data/mudata_objects/crc_232_no_mye_IgM.mudata.h5mu")
# Out:
# /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/mudata/_core/mudata.py:1598: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
# /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/mudata/_core/mudata.py:1461: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.

# %% [markdown]
# # GP

# %%
import os.path
from tempfile import TemporaryDirectory
from urllib.request import urlretrieve
import anndata as ad
import mudata as md
import numpy as np
import pandas as pd
import mofaflex as mfl
from plotnine import *
import os
from pathlib import Path
from anndata.compat import DaskArray
import dask.array as da
# Out:
# Importing the dtw module. When using in academic works please cite:
#   T. Giorgino. Computing and Visualizing Dynamic Time Warping Alignments in R: The dtw Package.
#   J. Stat. Soft., doi:10.18637/jss.v031.i07.

# %%
data_path = Path("/g/stegle/aalsayah/repos/data/mudata_objects/")
mdata = md.read(data_path/  "crc_222_no_mye_TC.mudata.h5mu")
md.set_options(pull_on_update=False)
# Out:
# /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/mudata/_core/mudata.py:1598: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
# /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/mudata/_core/mudata.py:1461: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.

# %%
model = mfl.MOFAFLEX(
    mdata,
    mfl.DataOptions(covariates_obsm_key="spatial"),
    mfl.ModelOptions(n_factors=15, factor_prior="GP", likelihoods="Normal"),
    mfl.TrainingOptions(batch_size=1000, 
                        n_particles=10,
                        seed=1, 
                        lr=0.005,
                        max_epochs=1000,
                        save_path= ('/g/stegle/aalsayah/repos/data/models_obj/sns_models/crc_222.sns.hdf5'),
                        early_stopper_patience=50),
                        
                        )
# Out:
# INFO	Initializing factors using `random` method...
#   0%|                                                                                                 | 0/1000…
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/poutine/trace_messenger.py:191, in TraceHandler.__call__(self, *args, **kwargs)
#     190 try:
# --> 191     ret = self.fn(*args, **kwargs)
#     192 except (ValueError, RuntimeError) as e:
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/poutine/messenger.py:32, in _context_wrap(context, fn, *args, **kwargs)
#      31 with context:
# ---> 32     return fn(*args, **kwargs)
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/poutine/messenger.py:32, in _context_wrap(context, fn, *args, **kwargs)
#      31 with context:
# ---> 32     return fn(*args, **kwargs)
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/poutine/messenger.py:32, in _context_wrap(context, fn, *args, **kwargs)
#      31 with context:
# ---> 32     return fn(*args, **kwargs)
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/nn/module.py:829, in pyro_method.<locals>.cached_fn(self, *args, **kwargs)
#     828 with self._pyro_context:
# --> 829     return fn(self, *args, **kwargs)
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/mofaflex/_core/pyro/model.py:261, in MofaFlexModel.model(self, data, sample_idx, nonmissing_samples, nonmissing_features, covariates, guiding_vars)
#     260 for prior in self._factors:
# --> 261     factors.update(prior.model(factor_plate, sample_plates, covariates=covariates))
#     263 for group_name, group_factors in factors.items():
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/nn/module.py:829, in pyro_method.<locals>.cached_fn(self, *args, **kwargs)
#     828 with self._pyro_context:
# --> 829     return fn(self, *args, **kwargs)
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/mofaflex/_core/pyro/priors/gaussian_process.py:101, in GP.model(self, factor_plate, nonfactor_plates, covariates, **kwargs)
#      96 with factor_plate, nonfactor_plate:
#      97     return dict(
#      98         zip(
#      99             self._names,
#     100             torch.split(
# --> 101                 pyro.sample("z", dist.Normal(f, 1 - outputscale)),
#     102                 tuple(covariates[g].shape[0] for g in gnames),
#     103                 dim=self._nonfactor_dim,
#     104             ),
#     105             strict=False,
#     106         )
#     107     )
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/primitives.py:189, in sample(name, fn, obs, obs_mask, infer, *args, **kwargs)
#     188 # apply the stack and return its return value
# --> 189 apply_stack(msg)
#     190 assert msg["value"] is not None  # type narrowing guaranteed by apply_stack
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/poutine/runtime.py:378, in apply_stack(initial_msg)
#     376 pointer = pointer + 1
# --> 378 frame._process_message(msg)
#     380 if msg["stop"]:
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/poutine/plate_messenger.py:25, in PlateMessenger._process_message(self, msg)
#      24 super()._process_message(msg)
# ---> 25 BroadcastMessenger._pyro_sample(msg)
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      80 with self._recreate_cm():
# ---> 81     return func(*args, **kwds)
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/poutine/broadcast_messenger.py:74, in BroadcastMessenger._pyro_sample(msg)
#      70 if (
#      71     target_batch_shape[f.dim] is not None
#      72     and target_batch_shape[f.dim] != f.size
#      73 ):
# ---> 74     raise ValueError(
#      75         "Shape mismatch inside plate('{}') at site {} dim {}, {} vs {}".format(
#      76             f.name,
#      77             msg["name"],
#      78             f.dim,
#      79             f.size,
#      80             target_batch_shape[f.dim],
#      81         )
#      82     )
#      83 target_batch_shape[f.dim] = f.size
#
# ValueError: Shape mismatch inside plate('gp_nonfactors') at site z dim -2, 1000 vs 10000
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 model = mfl.MOFAFLEX(
#       2     mdata,
#       3     mfl.DataOptions(covariates_obsm_key="spatial"),
#       4     mfl.ModelOptions(n_factors=15, factor_prior="GP", likelihoods="Normal"),
#       5     mfl.TrainingOptions(batch_size=1000,
#       6                         n_particles=10,
#       7                         seed=1,
#       8                         lr=0.005,
#       9                         max_epochs=1000,
#      10                         save_path= ('/g/stegle/aalsayah/repos/data/models_obj/sns_models/crc_222.sns.hdf5'),
#      11                         early_stopper_patience=50),
#      12
#      13                         )
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/mofaflex/_core/mofaflex.py:280, in MOFAFLEX.__init__(self, data, *args)
#     277 self._sample_names = data.sample_names
#     278 self._feature_names = data.feature_names
# --> 280 self._fit(data, preprocessor)
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/mofaflex/_core/mofaflex.py:933, in MOFAFLEX._fit(self, data, preprocessor)
#     931         batch = collate((batch,), collate_fn_map=collate_fn_map)
#     932         with self._train_opts.device:
# --> 933             epoch_loss += svi.step(
#     934                 **batch["data"], covariates=batch["covariates"], guiding_vars=batch["guiding_vars"]
#     935             )
#     936 train_loss_elbo.append(epoch_loss)
#     937 if (
#     938     self._gp is not None
#     939     and len(self._gp_opts.warp_groups)
#     940     and i > 0
#     941     and not i % self._gp_opts.warp_interval
#     942 ):
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/infer/svi.py:145, in SVI.step(self, *args, **kwargs)
#     143 # get loss and compute gradients
#     144 with poutine.trace(param_only=True) as param_capture:
# --> 145     loss = self.loss_and_grads(self.model, self.guide, *args, **kwargs)
#     147 params = set(
#     148     site["value"].unconstrained() for site in param_capture.trace.nodes.values()
#     149 )
#     151 # actually perform gradient steps
#     152 # torch.optim objects gets instantiated for any params that haven't been seen yet
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/infer/trace_elbo.py:140, in Trace_ELBO.loss_and_grads(self, model, guide, *args, **kwargs)
#     138 loss = 0.0
#     139 # grab a trace from the generator
# --> 140 for model_trace, guide_trace in self._get_traces(model, guide, args, kwargs):
#     141     loss_particle, surrogate_loss_particle = self._differentiable_loss_particle(
#     142         model_trace, guide_trace
#     143     )
#     144     loss += loss_particle / self.num_particles
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/infer/elbo.py:234, in ELBO._get_traces(self, model, guide, args, kwargs)
#     232     if self.max_plate_nesting == float("inf"):
#     233         self._guess_max_plate_nesting(model, guide, args, kwargs)
# --> 234     yield self._get_vectorized_trace(model, guide, args, kwargs)
#     235 else:
#     236     for i in range(self.num_particles):
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/infer/elbo.py:211, in ELBO._get_vectorized_trace(self, model, guide, args, kwargs)
#     205 def _get_vectorized_trace(self, model, guide, args, kwargs):
#     206     """
#     207     Wraps the model and guide to vectorize ELBO computation over
#     208     ``num_particles``, and returns a single trace from the wrapped model
#     209     and guide.
#     210     """
# --> 211     return self._get_trace(
#     212         self._vectorized_num_particles(model),
#     213         self._vectorized_num_particles(guide),
#     214         args,
#     215         kwargs,
#     216     )
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/infer/trace_mean_field_elbo.py:82, in TraceMeanField_ELBO._get_trace(self, model, guide, args, kwargs)
#      81 def _get_trace(self, model, guide, args, kwargs):
# ---> 82     model_trace, guide_trace = super()._get_trace(model, guide, args, kwargs)
#      83     if is_validation_enabled():
#      84         _check_mean_field_requirement(model_trace, guide_trace)
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/infer/trace_elbo.py:57, in Trace_ELBO._get_trace(self, model, guide, args, kwargs)
#      52 def _get_trace(self, model, guide, args, kwargs):
#      53     """
#      54     Returns a single trace from the guide, and the model that is run
#      55     against it.
#      56     """
# ---> 57     model_trace, guide_trace = get_importance_trace(
#      58         "flat", self.max_plate_nesting, model, guide, args, kwargs
#      59     )
#      60     if is_validation_enabled():
#      61         check_if_enumerated(guide_trace)
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/infer/enum.py:65, in get_importance_trace(graph_type, max_plate_nesting, model, guide, args, kwargs, detach)
#      63     if detach:
#      64         guide_trace.detach_()
# ---> 65     model_trace = poutine.trace(
#      66         poutine.replay(model, trace=guide_trace), graph_type=graph_type
#      67     ).get_trace(*args, **kwargs)
#      69 if is_validation_enabled():
#      70     check_model_guide_match(model_trace, guide_trace, max_plate_nesting)
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/poutine/trace_messenger.py:216, in TraceHandler.get_trace(self, *args, **kwargs)
#     208 def get_trace(self, *args, **kwargs) -> Trace:
#     209     """
#     210     :returns: data structure
#     211     :rtype: pyro.poutine.Trace
#    (...)    214     Calls this poutine and returns its trace instead of the function's return value.
#     215     """
# --> 216     self(*args, **kwargs)
#     217     return self.msngr.get_trace()
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/poutine/trace_messenger.py:198, in TraceHandler.__call__(self, *args, **kwargs)
#     196         exc = exc_type("{}\n{}".format(exc_value, shapes))
#     197         exc = exc.with_traceback(traceback)
# --> 198         raise exc from e
#     199     self.msngr.trace.add_node(
#     200         "_RETURN", name="_RETURN", type="return", value=ret
#     201     )
#     202 return ret
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/poutine/trace_messenger.py:191, in TraceHandler.__call__(self, *args, **kwargs)
#     187 self.msngr.trace.add_node(
#     188     "_INPUT", name="_INPUT", type="args", args=args, kwargs=kwargs
#     189 )
#     190 try:
# --> 191     ret = self.fn(*args, **kwargs)
#     192 except (ValueError, RuntimeError) as e:
#     193     exc_type, exc_value, traceback = sys.exc_info()
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/poutine/messenger.py:32, in _context_wrap(context, fn, *args, **kwargs)
#      25 def _context_wrap(
#      26     context: "Messenger",
#      27     fn: Callable,
#      28     *args: Any,
#      29     **kwargs: Any,
#      30 ) -> Any:
#      31     with context:
# ---> 32         return fn(*args, **kwargs)
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/poutine/messenger.py:32, in _context_wrap(context, fn, *args, **kwargs)
#      25 def _context_wrap(
#      26     context: "Messenger",
#      27     fn: Callable,
#      28     *args: Any,
#      29     **kwargs: Any,
#      30 ) -> Any:
#      31     with context:
# ---> 32         return fn(*args, **kwargs)
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/poutine/messenger.py:32, in _context_wrap(context, fn, *args, **kwargs)
#      25 def _context_wrap(
#      26     context: "Messenger",
#      27     fn: Callable,
#      28     *args: Any,
#      29     **kwargs: Any,
#      30 ) -> Any:
#      31     with context:
# ---> 32         return fn(*args, **kwargs)
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/nn/module.py:829, in pyro_method.<locals>.cached_fn(self, *args, **kwargs)
#     826 @functools.wraps(fn)
#     827 def cached_fn(self: _PyroModule, *args: _P.args, **kwargs: _P.kwargs) -> _T:
#     828     with self._pyro_context:
# --> 829         return fn(self, *args, **kwargs)
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/mofaflex/_core/pyro/model.py:261, in MofaFlexModel.model(self, data, sample_idx, nonmissing_samples, nonmissing_features, covariates, guiding_vars)
#     259 factors = {}
#     260 for prior in self._factors:
# --> 261     factors.update(prior.model(factor_plate, sample_plates, covariates=covariates))
#     263 for group_name, group_factors in factors.items():
#     264     if self._nonnegative_factors[group_name]:
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/nn/module.py:829, in pyro_method.<locals>.cached_fn(self, *args, **kwargs)
#     826 @functools.wraps(fn)
#     827 def cached_fn(self: _PyroModule, *args: _P.args, **kwargs: _P.kwargs) -> _T:
#     828     with self._pyro_context:
# --> 829         return fn(self, *args, **kwargs)
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/mofaflex/_core/pyro/priors/gaussian_process.py:101, in GP.model(self, factor_plate, nonfactor_plates, covariates, **kwargs)
#      94 outputscale = self._gp.outputscale.reshape(self._gp_shape)
#      96 with factor_plate, nonfactor_plate:
#      97     return dict(
#      98         zip(
#      99             self._names,
#     100             torch.split(
# --> 101                 pyro.sample("z", dist.Normal(f, 1 - outputscale)),
#     102                 tuple(covariates[g].shape[0] for g in gnames),
#     103                 dim=self._nonfactor_dim,
#     104             ),
#     105             strict=False,
#     106         )
#     107     )
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/primitives.py:189, in sample(name, fn, obs, obs_mask, infer, *args, **kwargs)
#     172 msg = Message(
#     173     type="sample",
#     174     name=name,
#    (...)    186     continuation=None,
#     187 )
#     188 # apply the stack and return its return value
# --> 189 apply_stack(msg)
#     190 assert msg["value"] is not None  # type narrowing guaranteed by apply_stack
#     191 return msg["value"]
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/poutine/runtime.py:378, in apply_stack(initial_msg)
#     375 for frame in reversed(stack):
#     376     pointer = pointer + 1
# --> 378     frame._process_message(msg)
#     380     if msg["stop"]:
#     381         break
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/poutine/plate_messenger.py:25, in PlateMessenger._process_message(self, msg)
#      23 def _process_message(self, msg: "Message") -> None:
#      24     super()._process_message(msg)
# ---> 25     BroadcastMessenger._pyro_sample(msg)
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# File /g/stegle/aalsayah/Miniforge3/envs/mofa_flex/lib/python3.11/site-packages/pyro/poutine/broadcast_messenger.py:74, in BroadcastMessenger._pyro_sample(msg)
#      69     target_batch_shape = prefix_batch_shape + target_batch_shape
#      70     if (
#      71         target_batch_shape[f.dim] is not None
#      72         and target_batch_shape[f.dim] != f.size
#      73     ):
# ---> 74         raise ValueError(
#      75             "Shape mismatch inside plate('{}') at site {} dim {}, {} vs {}".format(
#      76                 f.name,
#      77                 msg["name"],
#      78                 f.dim,
#      79                 f.size,
#      80                 target_batch_shape[f.dim],
#      81             )
#      82         )
#      83     target_batch_shape[f.dim] = f.size
#      84 # Starting from the right, if expected size is None at an index,
#      85 # set it to the actual size if it exists, else 1.
#
# ValueError: Shape mismatch inside plate('gp_nonfactors') at site z dim -2, 1000 vs 10000
#                                                                          Trace Shapes:
#                                                                           Param Sites:
#       _factors.0._gp$$$variational_strategy._variational_distribution.variational_mean           15 100
# _factors.0._gp$$$variational_strategy._variational_distribution.chol_variational_covar      15  100 100
#                               _factors.0._gp$$$_covar_module.group_kernel.covar_factor      15    1   1
#                                    _factors.0._gp$$$_covar_module.group_kernel.raw_var           15   1
#                             _factors.0._gp$$$_covar_module.base_kernel.raw_outputscale               15
#                 _factors.0._gp$$$_covar_module.base_kernel.base_kernel.raw_lengthscale      15    1   1
#                                                                          Sample Sites:
#                                                             plate_samples_group_1 dist                |
#                                                                                  value         1000   |
#                                                               plate_features_epi4 dist                |
#                                                                                  value           28   |
#                                                               plate_features_epi2 dist                |
#                                                                                  value           23   |
#                                                               plate_features_mye1 dist                |
#                                                                                  value           24   |
#                                                               plate_features_fib2 dist                |
#                                                                                  value           26   |
#                                                                 plate_features_EC dist                |
#                                                                                  value           25   |
#                                                             plate_features_PC_IgA dist                |
#                                                                                  value           25   |
#                                                             plate_features_PC_IgG dist                |
#                                                                                  value           25   |
#                                                               plate_features_epi1 dist                |
#                                                                                  value           21   |
#                                                                plate_features_SMC dist                |
#                                                                                  value           19   |
#                                                               plate_features_fib1 dist                |
#                                                                                  value           23   |
#                                                             plate_features_PC_IgM dist                |
#                                                                                  value           24   |
#                                                               plate_features_epi3 dist                |
#                                                                                  value           22   |
#                                                                plate_guiding_vars dist                |
#                                                                                  value            1   |
#                                                                     plate_factors dist                |
#                                                                                  value           15   |
#                                                                              gp.u dist 10 1  1    1   | 15 100
#                                                                                  value 10 1  1    1   | 15 100
#                                                                      gp.log_prior dist 10 1  1    1   |  0
#                                                                                  value                |  0
#                                                                     gp.added_loss dist 10 1  1    1   |  0
#                                                                                  value                |  0
#                                                                     gp_nonfactors dist                |
#                                                                                  value         1000   |
#                                                                          gp_batch dist                |
#                                                                                  value           15   |
#                                                                              gp.f dist 10 1 15 1000   |
#                                                                                  value 10 1 15 1000   |
